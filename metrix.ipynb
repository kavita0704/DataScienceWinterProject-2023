# %% [markdown]
# <a href="https://colab.research.google.com/github/kavita0704/DataScienceWinterProject-2023/blob/main/metrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Example path (adjust based on your folder)
file_path = '/content/drive/MyDrive/placement.csv'

df = pd.read_csv(file_path)
print(df.head())
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.title('CGPA vs Package')
plt.show()

# %%
X=df.iloc[:,0:1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
# Out:
# Text(0, 0.5, 'Package (LPA)')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175
# MSE 0.12129235313495527

# %%
print("R2_score",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2_score 0.780730147510384

# %%
#adjusted R2_score

# %%
X_test.shape
# Out:
# (40, 1)

# %%
1-((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415
